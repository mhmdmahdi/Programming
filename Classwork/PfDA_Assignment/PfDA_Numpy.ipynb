# %% [markdown]
# # Programming for Data Analysis Assignment

# %%
import numpy as np

# %%
rng = np.random.default_rng()
x = rng.random(1000)

# %%
print(x)
# Out:
# [3.86808752e-01 1.91923961e-01 7.77976960e-01 1.72790715e-01
#  4.32928711e-01 6.04783511e-01 4.51430606e-01 6.72714808e-02
#  2.00228757e-01 7.80977485e-01 3.00485994e-01 7.37093435e-01
#  4.14052898e-01 4.04294406e-01 4.06659003e-01 1.94614150e-01
#  1.71743551e-01 9.73102011e-02 6.62862618e-01 7.84497172e-02
#  6.09504238e-01 6.92663848e-01 9.97078697e-01 3.02134480e-01
#  7.30929653e-01 1.49503979e-01 1.06805446e-02 2.50058040e-01
#  5.20187840e-01 2.31848734e-01 7.36292205e-01 8.29849647e-01
#  6.07081423e-01 2.79200818e-01 3.17827994e-01 1.06565647e-01
#  2.34813224e-01 8.79774734e-01 6.44238266e-02 4.77183563e-01
#  4.27530582e-01 3.96694529e-01 4.34462819e-01 6.78785495e-01
#  7.33398256e-02 3.42728676e-01 5.23300419e-01 4.91932936e-01
#  1.57444216e-01 9.72856883e-01 4.70574649e-01 9.77977483e-01
#  2.56643165e-02 8.48071694e-01 9.75104958e-01 5.14055110e-01
#  2.03099792e-01 3.45021093e-01 6.46143703e-01 9.37385494e-01
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(x)
plt.show()

# %%
y = np.random.normal (0,0.01,100000)

# %%
plt.hist(y)
plt.show()

# %%
print(y)
# Out:
# [ 0.00338669  0.00444505  0.01150128 ... -0.00878076 -0.00431593
#  -0.0080766 ]

# %%
rng = np.random.default_rng(seed=42)

# %%
x = rng.random((5,3))

# %%
print(x)
# Out:
# [[0.77395605 0.43887844 0.85859792]
#  [0.69736803 0.09417735 0.97562235]
#  [0.7611397  0.78606431 0.12811363]
#  [0.45038594 0.37079802 0.92676499]
#  [0.64386512 0.82276161 0.4434142 ]]
